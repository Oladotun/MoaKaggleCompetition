# %% [markdown]
# ### Data exploration notebook for Kaggle `lish-moa` competition

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set()
sns.set_style('whitegrid')

# %%
import data_describe as dd

# %%
tf_df = pd.read_csv('../train_features.csv',index_col='sig_id')

# %% [markdown]
# ### 0-771 gene expression features, 0-99 cell viability features

# %%
tts_df = pd.read_csv('../train_targets_scored.csv',index_col='sig_id')

# %% [markdown]
# ### 206 targets
# #### *radically* uncorrelated with each other, although I'm not familiar with the properties of sparse datasets like this.

# %%
total_df = tf_df.join(tts_df)

# %%
dd.data_summary(total_df)
# Out:
#                       cp_type  cp_time cp_dose       g-0        g-1       g-2  \
# Data Type              object    int64  object   float64    float64   float64
# Mean                           48.0202          0.248366 -0.0956839  0.152253
# Standard Deviation             19.4028            1.3934   0.812363   1.03573
# Median                              48          -0.00885    -0.0466    0.0752
# Min                                 24            -5.513     -5.737    -9.104
# Max                                 72                10      5.039     8.257
# # Zeros                              0                22          4         8
# # Nulls                     0        0       0         0          0         0
# % Most Frequent Value   92.16    34.64   51.01      0.09       0.04      0.05
#
#                              g-3        g-4       g-5        g-6  ...  \
# Data Type                float64    float64   float64    float64  ...
# Mean                   0.0819714  0.0573468 -0.138836  0.0359605  ...
# Standard Deviation      0.950012    1.03209   1.17939   0.882395  ...
# Median                   0.00805    -0.0269  -0.01565   -0.00065  ...
# Min                       -5.998     -6.369       -10        -10  ...
# Max                           10         10     7.282      7.333  ...
# # Zeros                       48         15        12         15  ...
# # Nulls                        0          0         0          0  ...
# % Most Frequent Value        0.2       0.06      0.05       0.06  ...
#
#                       tropomyosin_receptor_kinase_inhibitor trpv_agonist  \
# Data Type                                             int64        int64
# Mean                                            0.000251953    0.0010498
# Standard Deviation                                0.0158713    0.0323843
# Median                                                    0            0
# Min                                                       0            0
# Max                                                       1            1
# # Zeros                                               23808        23789
# # Nulls                                                   0            0
# % Most Frequent Value                                 99.97         99.9
#
#                       trpv_antagonist tubulin_inhibitor  \
# Data Type                       int64             int64
# Mean                       0.00201562         0.0132695
# Standard Deviation          0.0448513          0.114429
# Median                              0                 0
# Min                                 0                 0
# Max                                 1                 1
# # Zeros                         23766             23498
# # Nulls                             0                 0
# % Most Frequent Value            99.8             98.67
#
#                       tyrosine_kinase_inhibitor  \
# Data Type                                 int64
# Mean                                 0.00306542
# Standard Deviation                    0.0552825
# Median                                        0
# Min                                           0
# Max                                           1
# # Zeros                                   23741
# # Nulls                                       0
# % Most Frequent Value                     99.69
#
#                       ubiquitin_specific_protease_inhibitor vegfr_inhibitor  \
# Data Type                                             int64           int64
# Mean                                            0.000251953      0.00713866
# Standard Deviation                                0.0158713       0.0841902
# Median                                                    0               0
# Min                                                       0               0
# Max                                                       1               1
# # Zeros                                               23808           23644
# # Nulls                                                   0               0
# % Most Frequent Value                                 99.97           99.29
#
#                         vitamin_b vitamin_d_receptor_agonist wnt_inhibitor
# Data Type                   int64                      int64         int64
# Mean                   0.00109179                 0.00163769    0.00125976
# Standard Deviation       0.033025                  0.0404361     0.0354715
# Median                          0                          0             0
# Min                             0                          0             0
# Max                             1                          1             1
# # Zeros                     23788                      23775         23784
# # Nulls                         0                          0             0
# % Most Frequent Value       99.89                      99.84         99.87
#
# [9 rows x 1081 columns]
# data-describe Summary Widget

# %%
dd.correlation_matrix(total_df,cluster=True)
# Out:
# <AxesSubplot:title={'center':'Correlation Matrix'}>

# %%
dd.scatter_plots(total_df, threshold={'Outlier': 0.9})

# %%
dd.cluster(total_df)
